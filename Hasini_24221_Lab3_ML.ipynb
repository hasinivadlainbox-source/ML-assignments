# %%
#Hasini V
#BL.SC.U4CSE24221
#ML_LAB 3

# %%
#A1.
Features are of different datatypes
Norminal datatype : Country, Marital_Status, Response, 
Ordinal : Education, Kidhome, Teenhome, 
Interval : Year_Birth, Dt_Customer, 
Ratio: Income
